# %%
# import dependencies
import pandas as pd

# %%
# read in csv file
sales = pd.read_csv('data/data_clean.csv')

# %%
# preview to make sure df looks correct
sales.head()
# Out:
#    id               Address         County    State Sale Date  Sale Year  \
# 0   1  2976 WHISPERWOOD TRL  Fulton County  Georgia   1/12/17       2017
# 1   2         3040 STONE RD  Fulton County  Georgia   1/13/17       2017
# 2   3       2995 REDWINE RD  Fulton County  Georgia   1/27/17       2017
# 3   4      2974 ROCKWOOD RD  Fulton County  Georgia    3/1/17       2017
# 4   5        3105 GOLDEN DR  Fulton County  Georgia    5/5/17       2017
#
#   Sale Month  Sale Price        lat       long         block
# 0        Jan      200000  33.671191 -84.485159  131210113031
# 1        Jan      220000  33.667964 -84.487987  131210113031
# 2        Jan      182000  33.660411 -84.486634  131210113031
# 3        Mar      149900  33.674489 -84.482433  131210113031
# 4        May      175000  33.672837 -84.489831  131210113031

# %%
# set index to id
sales.set_index('id', inplace=True)

# preview
sales.head()
# Out:
#                  Address         County    State Sale Date  Sale Year  \
# id
# 1   2976 WHISPERWOOD TRL  Fulton County  Georgia   1/12/17       2017
# 2          3040 STONE RD  Fulton County  Georgia   1/13/17       2017
# 3        2995 REDWINE RD  Fulton County  Georgia   1/27/17       2017
# 4       2974 ROCKWOOD RD  Fulton County  Georgia    3/1/17       2017
# 5         3105 GOLDEN DR  Fulton County  Georgia    5/5/17       2017
#
#    Sale Month  Sale Price        lat       long         block
# id
# 1         Jan      200000  33.671191 -84.485159  131210113031
# 2         Jan      220000  33.667964 -84.487987  131210113031
# 3         Jan      182000  33.660411 -84.486634  131210113031
# 4         Mar      149900  33.674489 -84.482433  131210113031
# 5         May      175000  33.672837 -84.489831  131210113031

# %%
# create shortened version to include as example on website
sales_example = sales.head(100)

# %%
# export to html
sales_example.to_html("sales_example.html")
